# %%
import pandas as pd

# %% [markdown]
# Считать данные с помощью pandas
# Вывести на экран первые 5 строк
#
#     1.1 Создать новый признак Cpu_Company, который будет содержать только название фирмы, которая произвела CPU (Intel, AMD и т.д)
#     1.2 Создать новый признак Memory_Amount, который будет содержать только количество Gb памяти без указания типа носителя (128, 1024, 256 и т.д.)
#     1.3 Создать новый признак Memory_Type, который будет содержать только тип носителя (HDD, SDD и т.д.)
#     1.4 Удалите признаки Memory и ScreenResolution

# %%
df = pd.read_csv('laptop_price.csv', encoding='cp1251')

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %%
df['Cpu_Company'] = df['Cpu'].apply(lambda x: x.split(' ')[0])

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros Cpu_Company
# 0      1339.69       Intel
# 1       898.94       Intel
# 2       575.00       Intel
# 3      2537.45       Intel
# 4      1803.60       Intel

# %%
df['Memory_second'] = df['Memory'].apply(lambda x: x.split(' ')[:])

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros Cpu_Company            Memory_second Memory_Amount
# 0      1339.69       Intel             [128GB, SSD]          None
# 1       898.94       Intel  [128GB, Flash, Storage]          None
# 2       575.00       Intel             [256GB, SSD]          None
# 3      2537.45       Intel             [512GB, SSD]          None
# 4      1803.60       Intel             [256GB, SSD]          None

# %%
def Take_nom(x: list):
    l = []
    for i in x:
        if '2' in i:
            l.append(i)
    
    return l.join('+')

# %%
df['Memory_second'] = df['Memory'].apply(lambda x: x.split(' ')[:])

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros Cpu_Company            Memory_second Memory_Amount
# 0      1339.69       Intel             [128GB, SSD]          None
# 1       898.94       Intel  [128GB, Flash, Storage]          None
# 2       575.00       Intel             [256GB, SSD]          None
# 3      2537.45       Intel             [512GB, SSD]          None
# 4      1803.60       Intel             [256GB, SSD]          None

# %% [markdown]
# Создайте датафрейм с клиентами:
#
# clients = pd.DataFrame({
#     'client_id': [45, 32, 67, 33, 43],
#     'laptop_id': [506, 398, 710, 120, 1999]
# })
#
#     laptop_id - это индексы датафрейма с ноутбуками
#     3.1 Присоедините к таблице clients данные по ноутбукам через метод join
#     3.2 Присоедините к таблице clients данные по ноутбукам через метод merge

# %%
clients = pd.DataFrame({
    'client_id': [45, 32, 67, 33, 43],
    'laptop_id': [506, 398, 710, 120, 1999]
})

# %%
clients_lap = clients.set_index('laptop_id')

# %%
clients_lap
# Out:
#            client_id
# laptop_id
# 506               45
# 398               32
# 710               67
# 120               33
# 1999              43

# %%
date = clients_lap.join(df)

# %%
date
# Out:
#            client_id  laptop_ID Company                 Product     TypeName  \
# laptop_id
# 506               45      513.0    Asus  ZenBook UX510UX-CN211T     Notebook
# 398               32      405.0    Dell         Precision M5520  Workstation
# 710               67      718.0  Lenovo      Legion Y520-15IKBN       Gaming
# 120               33      123.0    Acer                  Spin 3     Notebook
# 1999              43        NaN     NaN                     NaN          NaN
#
#            Inches                           ScreenResolution  \
# laptop_id
# 506          15.6                          Full HD 1920x1080
# 398          15.6        4K Ultra HD / Touchscreen 3840x2160
# 710          15.6                IPS Panel Full HD 1920x1080
# 120          15.6  IPS Panel Full HD / Touchscreen 1920x1080
# 1999          NaN                                        NaN
#
#                                    Cpu  Ram                Memory  \
# laptop_id
# 506         Intel Core i7 7500U 2.7GHz  8GB  256GB SSD +  1TB HDD
# 398        Intel Core i7 7700HQ 2.8GHz  8GB             256GB SSD
# 710        Intel Core i7 7700HQ 2.8GHz  8GB  128GB SSD +  1TB HDD
# 120         Intel Core i3 7100U 2.4GHz  6GB               1TB HDD
# 1999                               NaN  NaN                   NaN
#
#                                   Gpu       OpSys  Weight  Price_euros  \
# laptop_id
# 506             Intel HD Graphics 620  Windows 10     2kg       1224.0
# 398               Nvidia Quadro M1200  Windows 10  1.78kg       2712.0
# 710        Nvidia GeForce GTX 1050 Ti  Windows 10   2.5kg       1249.0
# 120             Intel HD Graphics 620  Windows 10   2.1kg        479.0
# 1999                              NaN         NaN     NaN          NaN
#
#           Cpu_Company                Memory_second Memory_Amount
# laptop_id
# 506             Intel  [256GB, SSD, +, , 1TB, HDD]          None
# 398             Intel                 [256GB, SSD]          None
# 710             Intel  [128GB, SSD, +, , 1TB, HDD]          None
# 120             Intel                   [1TB, HDD]          None
# 1999              NaN                          NaN           NaN

# %%
df['laptop_id'] = df.index

# %%
date_2 = clients.merge(df, on='laptop_id')

# %%
date_2
# Out:
#    client_id  laptop_id  laptop_ID Company                 Product  \
# 0         45        506        506    Asus  ZenBook UX510UX-CN211T
# 1         32        398        398    Dell         Precision M5520
# 2         67        710        710  Lenovo      Legion Y520-15IKBN
# 3         33        120        120    Acer                  Spin 3
#
#       TypeName  Inches                           ScreenResolution  \
# 0     Notebook    15.6                          Full HD 1920x1080
# 1  Workstation    15.6        4K Ultra HD / Touchscreen 3840x2160
# 2       Gaming    15.6                IPS Panel Full HD 1920x1080
# 3     Notebook    15.6  IPS Panel Full HD / Touchscreen 1920x1080
#
#                            Cpu  Ram                Memory  \
# 0   Intel Core i7 7500U 2.7GHz  8GB  256GB SSD +  1TB HDD
# 1  Intel Core i7 7700HQ 2.8GHz  8GB             256GB SSD
# 2  Intel Core i7 7700HQ 2.8GHz  8GB  128GB SSD +  1TB HDD
# 3   Intel Core i3 7100U 2.4GHz  6GB               1TB HDD
#
#                           Gpu       OpSys  Weight  Price_euros Cpu_Company  \
# 0       Intel HD Graphics 620  Windows 10     2kg       1224.0       Intel
# 1         Nvidia Quadro M1200  Windows 10  1.78kg       2712.0       Intel
# 2  Nvidia GeForce GTX 1050 Ti  Windows 10   2.5kg       1249.0       Intel
# 3       Intel HD Graphics 620  Windows 10   2.1kg        479.0       Intel
#
#                  Memory_second Memory_Amount
# 0  [256GB, SSD, +, , 1TB, HDD]          None
# 1                 [256GB, SSD]          None
# 2  [128GB, SSD, +, , 1TB, HDD]          None
# 3                   [1TB, HDD]          None

# %% [markdown]
# Найдите среднюю стоимость ноутбуков в зависимости от компании производителя
# Отсортируйте от меньшей стоимости к большей

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          0   Apple  MacBook Pro  Ultrabook    13.3
# 1          1   Apple  Macbook Air  Ultrabook    13.3
# 2          2      HP       250 G6   Notebook    15.6
# 3          3   Apple  MacBook Pro  Ultrabook    15.4
# 4          4   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros Cpu_Company            Memory_second Memory_Amount  laptop_id
# 0      1339.69       Intel             [128GB, SSD]          None          0
# 1       898.94       Intel  [128GB, Flash, Storage]          None          1
# 2       575.00       Intel             [256GB, SSD]          None          2
# 3      2537.45       Intel             [512GB, SSD]          None          3
# 4      1803.60       Intel             [256GB, SSD]          None          4

# %%
df.groupby('Company').agg({'Price_euros': 'mean'}).sort_values('Price_euros')
# Out:
#            Price_euros
# Company
# Vero        217.425000
# Mediacom    295.000000
# Chuwi       314.296667
# Acer        626.775825
# Fujitsu     729.000000
# HP         1067.774854
# Lenovo     1086.384444
# Asus       1104.169367
# Xiaomi     1133.462500
# Dell       1186.068990
# Toshiba    1267.812500
# Samsung    1413.444444
# Huawei     1424.000000
# Apple      1564.198571
# Microsoft  1612.308333
# Google     1677.666667
# MSI        1728.908148
# LG         2099.000000
# Razer      3346.142857

# %% [markdown]
# Найдите минимальную, среднюю и максимальную стоимости ноутбуков в зависимости от производителя процессора

# %%
df.groupby('Cpu_Company').agg({'Price_euros': ['min', 'mean', 'max']})
# Out:
#             Price_euros
#                     min         mean     max
# Cpu_Company
# AMD               199.0   560.638871  2199.0
# Intel             174.0  1152.214145  6099.0
# Samsung           659.0   659.000000   659.0
